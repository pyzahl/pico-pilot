# %%
from PIL import Image
#test2 = Image.open('WhatsApp Image 2022-06-30 at 1.18.21 PM.jpeg').convert("RGB")
test3 = Image.open('CUT.png')
test4 = Image.open('test.png')

# %%
import matplotlib.pyplot as plt
import cv2
plt.figure('overlay.png')
plt.imshow(test3, 'gray', interpolation='none')
plt.imshow(test4, 'jet', interpolation='none', alpha=1)
#plt.show('overlay.png')
plt.savefig('overlay.png')

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(test3)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(test4)

# %% [markdown]
# ##
